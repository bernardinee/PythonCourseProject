# %% [markdown]
# Name: *__Bernardine Adusei-Okrah__*
# ID: *__11123762__*
# Class: *__Computer Engineering__*

# %% [markdown]
# ***************************************************************************

# %% [markdown]
# __Section 1: Data Loading__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.read_csv(r"C:\Users\Bernardine Adusei\Desktop\11123762\red_wine.csv")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ************************

# %% [markdown]
# __Section 2: Exploratory Data Analysis__

# %%
red_wine_df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wine_df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
red_wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
red_wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ******************

# %% [markdown]
# __Summary Statistics__

# %%
red_wine_data = pd.read_csv(r"C:\Users\Bernardine Adusei\Desktop\11123762\red_wine.csv")
summary_stats = red_wine_data.describe()
print(summary_stats)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
#  **********************************************************************************************

# %% [markdown]
# __Section 3: Visualizations__

# %% [markdown]
# __Plots and Graphs__

# %% [markdown]
# *******************

# %% [markdown]
# 1) Histogram of Alcohol Content

# %%
plt.figure(figsize=(8, 6))
plt.hist(red_wine_data['alcohol'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram of Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2) Scatter Plot: Quality vs. Alcohol

# %%
plt.figure(figsize=(10, 6))
plt.scatter(red_wine_data['quality'], red_wine_data['alcohol'], color='blue', alpha=0.7)
plt.title('Quality vs. Alcohol Content')
plt.xlabel('Quality')
plt.ylabel('Alcohol Content')
plt.show()

# %% [markdown]
# 3) Pie Chart: pH Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r"C:\Users\Bernardine Adusei\Desktop\11123762\red_wine.csv"
df = pd.read_csv(file_path)
pH_counts = df['pH'].value_counts()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))

ax1.pie(pH_counts, labels=pH_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
ax1.set_title('Distribution of pH in Red Wine')
ax1.axis('equal')

table_data = pd.DataFrame({'pH Value': pH_counts.index, 'Count': pH_counts}).sort_values(by='pH Value')
table = ax2.table(cellText=table_data.values, colLabels=table_data.columns, cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)  

ax2.axis('off')
plt.show()

# %% [markdown]
# 4) Bar Chart: Average Sulphates by Quality

# %%
average_sulphates = red_wine_data.groupby('quality')['sulphates'].mean()

plt.figure(figsize=(8, 6))
average_sulphates.plot(kind='bar', color='blue')
plt.title('Average Sulphates by Quality')
plt.xlabel('Quality')
plt.ylabel('Average Sulphates')
plt.show()

# %% [markdown]
# 5)  Line Plot: Trend in Alcohol Content Over Index

# %%
plt.figure(figsize=(10, 6))
plt.plot(red_wine_data.index, red_wine_data['alcohol'], marker='o', color='blue')
plt.title('Trend in Alcohol Content Over Index')
plt.xlabel('Index')
plt.ylabel('Alcohol Content')
plt.show()

# %% [markdown]
# 6) Bar Graph - Quality Distribution

# %%
quality_counts = red_wine_df['quality'].value_counts().sort_index()
plt.bar(quality_counts.index, quality_counts.values, color='blue')
plt.title('Wine Quality Distribution')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 7) Residual Sugar Distribution

# %%
plt.hist(red_wine_df['residual sugar'], bins=30, color='lightblue', edgecolor='black')
plt.title('Residual Sugar Distribution')
plt.xlabel('Residual Sugar (g/dm^3)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 8) Scatter Plot of Alcohol vs. Residual Sugar

# %%
plt.scatter(x=red_wine_df['alcohol'], y=red_wine_df['residual sugar'], c=red_wine_df['quality'], cmap='viridis')
plt.colorbar(label='Quality')
plt.title('Alcohol vs. Residual Sugar')
plt.xlabel('Alcohol Content')
plt.ylabel('Residual Sugar')
plt.show()

# %% [markdown]
# 9) Density Curve of pH in Red Wine

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

file_path = r"C:\Users\Bernardine Adusei\Desktop\11123762\red_wine.csv"
df = pd.read_csv(file_path)

pH_values = df['pH'].values

density, bins, _ = plt.hist(pH_values, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black')

kernel_density = (1 / (density.sum() * np.diff(bins))) * np.exp(-(bins[:-1] + np.diff(bins) / 2 - pH_values[:, None])**2 / (2 * np.std(pH_values)**2))

plt.plot(bins[:-1], kernel_density.sum(axis=0), color='blue', label='Density Curve')

plt.title('Density Curve of pH in Red Wine')
plt.xlabel('pH')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# 10) Violin Plot for pH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = r"C:\Users\Bernardine Adusei\Desktop\11123762\red_wine.csv"
df = pd.read_csv(file_path)

plt.figure(figsize=(10, 6))
plt.violinplot(df['pH'], vert=False, showmeans=True, showextrema=True, showmedians=True)
plt.title('Violin Plot of pH in Red Wine')
plt.xlabel('pH')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# 11. Histogram of Random Data

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)  
plt.hist(data, bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Random Data')
plt.xlabel('Alcohol Density')
plt.ylabel('Quality')
plt.show()

# %% [markdown]
# *************

# %% [markdown]
# __Comprehensive Report__

# %% [markdown]
# **********************

# %% [markdown]
#  1) __Histogram of Alcohol Content__

# %% [markdown]
# The histogram provides a visual representation of the distribution of alcohol content in the red wine dataset.
#
# The histogram visualizes the distribution of alcohol content in the red wine dataset.
# It provides insights into the prevalent range of alcohol content.
# Bins are set to 20 for granularity, offering a detailed distribution view.
# Winemakers and consumers can use this information for decision-making.
# Overall, the histogram is a valuable tool for understanding the central tendency and spread of alcohol content in the dataset.

# %% [markdown]
# 2) __Scatter Plot - Quality vs. Alcohol Content__

# %% [markdown]
# The scatter plot visualizes the relationship between wine quality and alcohol content in the red wine dataset.
# Each point on the plot represents a red wine sample, with its quality on the x-axis and alcohol content on the y-axis.
# A blue color palette is used for clarity, and an alpha value of 0.7 adds transparency to better visualize overlapping points.
# The plot suggests patterns or trends in how alcohol content relates to the perceived quality of red wines.
# This visual representation serves as a quick reference for understanding potential correlations between quality ratings and alcohol content.

# %% [markdown]
# 3) __Pie Chart - pH Distribution__

# %% [markdown]
# The pie chart illustrates the distribution of pH values in the red wine dataset.
# Each slice of the pie corresponds to a unique pH value, and the size of each slice represents the frequency of occurrence.
# Colors from the Paired colormap enhance visual appeal, distinguishing between different pH values.
# Percentages are labeled on each slice using the autopct parameter, providing a clear indication of the proportion of each pH value in the dataset.
# The chart is titled "Distribution of pH in Red Wine," and the axis is set to equal for accurate representation.

# %% [markdown]
# 4) __Bar Chart - Average Sulphates by Quality__

# %% [markdown]
# The bar chart visualizes the average sulphate content grouped by wine quality in the red wine dataset.
# Quality levels are represented on the x-axis, and the corresponding average sulphate values are shown on the y-axis.
# The chart uses a blue color scheme for clarity and visual appeal.
# The vertical bars offer a clear comparison of sulphate levels across different quality ratings.
# The chart aids in quickly identifying trends or differences in sulphate content based on wine quality.

# %% [markdown]
# 5) __Line Plot - Trend in Alcohol Content Over Index__

# %% [markdown]
# The line plot illustrates the variation in alcohol content over the index (position) of red wine samples in the dataset.
# Each data point on the line represents a specific red wine sample, with the x-axis denoting its index and the y-axis indicating its alcohol content.
# A blue color scheme is employed for clarity, and markers ('o') highlight individual data points for emphasis.
# The upward or downward trends in the line indicate the overall direction of change in alcohol content across the dataset.
# The plot is titled "Trend in Alcohol Content Over Index" and provides a visual reference for understanding the general pattern in alcohol content distribution.

# %% [markdown]
# 6) __Bar Graph - Quality Distribution__

# %% [markdown]
# The bar graph visualizes the distribution of wine quality ratings in the red wine dataset.
# Quality levels are displayed on the x-axis, while the corresponding count of wines for each quality is shown on the y-axis.
# A blue color scheme is applied for clarity and visual appeal.
# The chart provides a clear comparison of the count of wines across different quality ratings.
# Titled "Wine Quality Distribution," this graph offers a quick overview of the prevalence of each quality rating in the dataset.

# %% [markdown]
# 7) __Histogram - Residual Sugar Distribution__

# %% [markdown]
# The histogram visualizes the distribution of residual sugar levels in red wines from the dataset.
# Residual sugar values are grouped into bins, with the x-axis representing the range of residual sugar content (measured in g/dm^3).
# The y-axis indicates the frequency of occurrence within each bin.
# A light blue color is chosen for the bars, and black edges enhance the visibility of the histogram.
# Titled "Residual Sugar Distribution," this histogram provides a quick understanding of the prevalence of different residual sugar levels in the dataset.

# %% [markdown]
# 8) __Scatter Plot - Alcohol vs. Residual Sugar__

# %% [markdown]
# The scatter plot visualizes the relationship between alcohol content and residual sugar levels in red wines.
# The x-axis represents alcohol content, the y-axis represents residual sugar, and each point represents a red wine sample.
# The color of each point is determined by its quality rating, providing a visual dimension to quality distribution.
# The colormap 'viridis' is applied to represent different quality levels with distinct colors.
# Titled "Alcohol vs. Residual Sugar," the plot allows for the identification of trends, clusters, or patterns in the dataset.

# %% [markdown]
# 9) __Density Curve - pH in Red Wine__

# %% [markdown]
# The plot depicts a density curve representing the distribution of pH values in the red wine dataset.
# The blue histogram in the background provides a visual representation of the observed pH value distribution, while the density curve overlays this histogram.
# Density Estimation is applied to estimate the probability density function of the pH values, creating a smooth curve.
# A transparency level of 0.7 is utilized, enhancing clarity by allowing a clear view of the density curve.
# Titled "Density Curve of pH in Red Wine," the plot provides insights into the continuous distribution of pH values and highlights potential concentration areas.

# %% [markdown]
# 10) __Violin Plot - pH in Red Wine__

# %% [markdown]
# The violin plot provides a comprehensive visualization of the distribution of pH values in the red wine dataset.
# The horizontal presentation (set by vert=False) enhances clarity in displaying the spread and density of pH values.
# Visual elements such as means, extrema, and medians are incorporated for a detailed representation of central tendencies and variability.
# The width of the violin plot at different pH levels represents the density of observations, offering insights into concentration areas.
# Titled "Violin Plot of pH in Red Wine," this plot effectively communicates the distribution of pH values, highlighting key statistical measures and overall trends.

# %% [markdown]
# 11) __Histogram of Random Data__

# %% [markdown]
# The histogram is generated from a set of random data using np.random.randn(1000), creating 1000 samples from a standard normal distribution.
# The histogram is represented with 30 bins, providing a visual breakdown of the distribution of random data values.
# The histogram bars are colored in 'blue,' enhancing visual appeal. The edges of the bars are outlined in black, aiding in better distinction.
# The x-axis is labeled as 'Alcohol Density,' indicating the variable under consideration, while the y-axis is labeled as 'Quality.'
# The title 'Histogram of Random Data' succinctly communicates the purpose of the visualization, informing the viewer that the chart represents the distribution of randomly generated data.

# %% [markdown]
# *******************************************************************
